# %% [markdown]
# # WGAN Training

# %% [markdown]
# ## imports

# %%
# %matplotlib inline

import os
import numpy as np
import matplotlib.pyplot as plt

from models.WGAN_old import WGAN
from utils.loaders import load_safari, load_cifar10
# Out:
# Using TensorFlow backend.

# %%
RUN_ID = '0032'
RUN_FOLDER = os.path.join("./run", RUN_ID)

BATCH_SIZE = 64
IMAGE_SIZE = 32

# %% [markdown]
# ## data

# %%
label = 7
(x_train, y_train) = load_cifar10(label)
# (x_train, y_train) = load_safari('elephant')

# %% [markdown]
# ## architecture

# %%
plt.imshow(x_train[0,:,:,:])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print(np.min(x_train))
print(np.max(x_train))
# Out:
# -1.0
# 1.0

# %%
x_train.shape
# Out:
# (5000, 32, 32, 3)

# %%
#works

gan = WGAN(input_dim = (IMAGE_SIZE,IMAGE_SIZE,3)
        , discriminator_conv_filters = [64,64,128,128]
        , discriminator_conv_kernel_size = [5,5,5,5]
        , discriminator_conv_strides = [2,2,2,1]
        , discriminator_conv_padding = 'same'
        , discriminator_batch_norm_momentum = None
        , discriminator_activation = 'leaky_relu'
        , discriminator_dropout_rate = None
        , discriminator_learning_rate = 0.00005
        , generator_initial_dense_layer_size = (8, 8, 64)
        , generator_use_upsampling = [True,True, False,False]
        , generator_conv_t_filters = [128,64, 64,3]
        , generator_conv_t_kernel_size = [5,5,5,5]
        , generator_conv_t_strides = [1,1,1,1]
        , generator_conv_t_padding = 'same'
        , generator_batch_norm_momentum = 0.8
        , generator_activation = 'leaky_relu'
        , generator_dropout_rate = None
        , generator_learning_rate = 0.00005
        , optimiser = 'rmsprop'
        , z_dim = 100
        )


gan.save(RUN_FOLDER)

# %%
print(gan.model.to_json(indent=4))
# Out:
# {
#     "class_name": "Model",
#     "config": {
#         "name": "model_3",
#         "layers": [
#             {
#                 "name": "model_input",
#                 "class_name": "InputLayer",
#                 "config": {
#                     "batch_input_shape": [
#                         null,
#                         100
#                     ],
#                     "dtype": "float32",
#                     "sparse": false,
#                     "name": "model_input"
#                 },
#                 "inbound_nodes": []
#             },
#             {
#                 "name": "model_2",
#                 "class_name": "Model",
#                 "config": {
#                     "name": "model_2",
#                     "layers": [
#                         {
#                             "name": "generator_input",
#                             "class_name": "InputLayer",
#                             "config": {
#                                 "batch_input_shape": [
#                                     null,
#                                     100
#                                 ],
#                                 "dtype": "float32",
#                                 "sparse": false,
#                                 "name": "generator_input"
#                             },
#                             "inbound_nodes": []
#                         },
#                         {
#                             "name": "dense_2",
#                             "class_name": "Dense",
#                             "config": {
#                                 "name": "dense_2",
#                                 "trainable": true,
#                                 "units": 4096,
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "generator_input",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "batch_normalization_1",
#                             "class_name": "BatchNormalization",
#                             "config": {
#                                 "name": "batch_normalization_1",
#                                 "trainable": true,
#                                 "axis": -1,
#                                 "momentum": 0.8,
#                                 "epsilon": 0.001,
#                                 "center": true,
#                                 "scale": true,
#                                 "beta_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "gamma_initializer": {
#                                     "class_name": "Ones",
#                                     "config": {}
#                                 },
#                                 "moving_mean_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "moving_variance_initializer": {
#                                     "class_name": "Ones",
#                                     "config": {}
#                                 },
#                                 "beta_regularizer": null,
#                                 "gamma_regularizer": null,
#                                 "beta_constraint": null,
#                                 "gamma_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "dense_2",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "leaky_re_lu_5",
#                             "class_name": "LeakyReLU",
#                             "config": {
#                                 "name": "leaky_re_lu_5",
#                                 "trainable": true,
#                                 "alpha": 0.20000000298023224
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "batch_normalization_1",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "reshape_1",
#                             "class_name": "Reshape",
#                             "config": {
#                                 "name": "reshape_1",
#                                 "trainable": true,
#                                 "target_shape": [
#                                     8,
#                                     8,
#                                     64
#                                 ]
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "leaky_re_lu_5",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "up_sampling2d_1",
#                             "class_name": "UpSampling2D",
#                             "config": {
#                                 "name": "up_sampling2d_1",
#                                 "trainable": true,
#                                 "size": [
#                                     2,
#                                     2
#                                 ],
#                                 "data_format": "channels_last",
#                                 "interpolation": "nearest"
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "reshape_1",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "generator_conv_t_0",
#                             "class_name": "Conv2DTranspose",
#                             "config": {
#                                 "name": "generator_conv_t_0",
#                                 "trainable": true,
#                                 "filters": 128,
#                                 "kernel_size": [
#                                     5,
#                                     5
#                                 ],
#                                 "strides": [
#                                     1,
#                                     1
#                                 ],
#                                 "padding": "same",
#                                 "data_format": "channels_last",
#                                 "dilation_rate": [
#                                     1,
#                                     1
#                                 ],
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null,
#                                 "output_padding": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "up_sampling2d_1",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "batch_normalization_2",
#                             "class_name": "BatchNormalization",
#                             "config": {
#                                 "name": "batch_normalization_2",
#                                 "trainable": true,
#                                 "axis": -1,
#                                 "momentum": 0.8,
#                                 "epsilon": 0.001,
#                                 "center": true,
#                                 "scale": true,
#                                 "beta_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "gamma_initializer": {
#                                     "class_name": "Ones",
#                                     "config": {}
#                                 },
#                                 "moving_mean_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "moving_variance_initializer": {
#                                     "class_name": "Ones",
#                                     "config": {}
#                                 },
#                                 "beta_regularizer": null,
#                                 "gamma_regularizer": null,
#                                 "beta_constraint": null,
#                                 "gamma_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "generator_conv_t_0",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "leaky_re_lu_6",
#                             "class_name": "LeakyReLU",
#                             "config": {
#                                 "name": "leaky_re_lu_6",
#                                 "trainable": true,
#                                 "alpha": 0.20000000298023224
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "batch_normalization_2",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "up_sampling2d_2",
#                             "class_name": "UpSampling2D",
#                             "config": {
#                                 "name": "up_sampling2d_2",
#                                 "trainable": true,
#                                 "size": [
#                                     2,
#                                     2
#                                 ],
#                                 "data_format": "channels_last",
#                                 "interpolation": "nearest"
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "leaky_re_lu_6",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "generator_conv_t_1",
#                             "class_name": "Conv2DTranspose",
#                             "config": {
#                                 "name": "generator_conv_t_1",
#                                 "trainable": true,
#                                 "filters": 64,
#                                 "kernel_size": [
#                                     5,
#                                     5
#                                 ],
#                                 "strides": [
#                                     1,
#                                     1
#                                 ],
#                                 "padding": "same",
#                                 "data_format": "channels_last",
#                                 "dilation_rate": [
#                                     1,
#                                     1
#                                 ],
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null,
#                                 "output_padding": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "up_sampling2d_2",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "batch_normalization_3",
#                             "class_name": "BatchNormalization",
#                             "config": {
#                                 "name": "batch_normalization_3",
#                                 "trainable": true,
#                                 "axis": -1,
#                                 "momentum": 0.8,
#                                 "epsilon": 0.001,
#                                 "center": true,
#                                 "scale": true,
#                                 "beta_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "gamma_initializer": {
#                                     "class_name": "Ones",
#                                     "config": {}
#                                 },
#                                 "moving_mean_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "moving_variance_initializer": {
#                                     "class_name": "Ones",
#                                     "config": {}
#                                 },
#                                 "beta_regularizer": null,
#                                 "gamma_regularizer": null,
#                                 "beta_constraint": null,
#                                 "gamma_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "generator_conv_t_1",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "leaky_re_lu_7",
#                             "class_name": "LeakyReLU",
#                             "config": {
#                                 "name": "leaky_re_lu_7",
#                                 "trainable": true,
#                                 "alpha": 0.20000000298023224
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "batch_normalization_3",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "generator_conv_t_2",
#                             "class_name": "Conv2DTranspose",
#                             "config": {
#                                 "name": "generator_conv_t_2",
#                                 "trainable": true,
#                                 "filters": 64,
#                                 "kernel_size": [
#                                     5,
#                                     5
#                                 ],
#                                 "strides": [
#                                     1,
#                                     1
#                                 ],
#                                 "padding": "same",
#                                 "data_format": "channels_last",
#                                 "dilation_rate": [
#                                     1,
#                                     1
#                                 ],
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null,
#                                 "output_padding": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "leaky_re_lu_7",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "batch_normalization_4",
#                             "class_name": "BatchNormalization",
#                             "config": {
#                                 "name": "batch_normalization_4",
#                                 "trainable": true,
#                                 "axis": -1,
#                                 "momentum": 0.8,
#                                 "epsilon": 0.001,
#                                 "center": true,
#                                 "scale": true,
#                                 "beta_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "gamma_initializer": {
#                                     "class_name": "Ones",
#                                     "config": {}
#                                 },
#                                 "moving_mean_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "moving_variance_initializer": {
#                                     "class_name": "Ones",
#                                     "config": {}
#                                 },
#                                 "beta_regularizer": null,
#                                 "gamma_regularizer": null,
#                                 "beta_constraint": null,
#                                 "gamma_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "generator_conv_t_2",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "leaky_re_lu_8",
#                             "class_name": "LeakyReLU",
#                             "config": {
#                                 "name": "leaky_re_lu_8",
#                                 "trainable": true,
#                                 "alpha": 0.20000000298023224
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "batch_normalization_4",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "generator_conv_t_3",
#                             "class_name": "Conv2DTranspose",
#                             "config": {
#                                 "name": "generator_conv_t_3",
#                                 "trainable": true,
#                                 "filters": 3,
#                                 "kernel_size": [
#                                     5,
#                                     5
#                                 ],
#                                 "strides": [
#                                     1,
#                                     1
#                                 ],
#                                 "padding": "same",
#                                 "data_format": "channels_last",
#                                 "dilation_rate": [
#                                     1,
#                                     1
#                                 ],
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null,
#                                 "output_padding": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "leaky_re_lu_8",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "activation_1",
#                             "class_name": "Activation",
#                             "config": {
#                                 "name": "activation_1",
#                                 "trainable": true,
#                                 "activation": "tanh"
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "generator_conv_t_3",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         }
#                     ],
#                     "input_layers": [
#                         [
#                             "generator_input",
#                             0,
#                             0
#                         ]
#                     ],
#                     "output_layers": [
#                         [
#                             "activation_1",
#                             0,
#                             0
#                         ]
#                     ]
#                 },
#                 "inbound_nodes": [
#                     [
#                         [
#                             "model_input",
#                             0,
#                             0,
#                             {}
#                         ]
#                     ]
#                 ]
#             },
#             {
#                 "name": "model_1",
#                 "class_name": "Model",
#                 "config": {
#                     "name": "model_1",
#                     "layers": [
#                         {
#                             "name": "discriminator_input",
#                             "class_name": "InputLayer",
#                             "config": {
#                                 "batch_input_shape": [
#                                     null,
#                                     32,
#                                     32,
#                                     3
#                                 ],
#                                 "dtype": "float32",
#                                 "sparse": false,
#                                 "name": "discriminator_input"
#                             },
#                             "inbound_nodes": []
#                         },
#                         {
#                             "name": "discriminator_conv_0",
#                             "class_name": "Conv2D",
#                             "config": {
#                                 "name": "discriminator_conv_0",
#                                 "trainable": false,
#                                 "filters": 64,
#                                 "kernel_size": [
#                                     5,
#                                     5
#                                 ],
#                                 "strides": [
#                                     2,
#                                     2
#                                 ],
#                                 "padding": "same",
#                                 "data_format": "channels_last",
#                                 "dilation_rate": [
#                                     1,
#                                     1
#                                 ],
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "discriminator_input",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "leaky_re_lu_1",
#                             "class_name": "LeakyReLU",
#                             "config": {
#                                 "name": "leaky_re_lu_1",
#                                 "trainable": false,
#                                 "alpha": 0.20000000298023224
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "discriminator_conv_0",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "discriminator_conv_1",
#                             "class_name": "Conv2D",
#                             "config": {
#                                 "name": "discriminator_conv_1",
#                                 "trainable": false,
#                                 "filters": 64,
#                                 "kernel_size": [
#                                     5,
#                                     5
#                                 ],
#                                 "strides": [
#                                     2,
#                                     2
#                                 ],
#                                 "padding": "same",
#                                 "data_format": "channels_last",
#                                 "dilation_rate": [
#                                     1,
#                                     1
#                                 ],
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "leaky_re_lu_1",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "leaky_re_lu_2",
#                             "class_name": "LeakyReLU",
#                             "config": {
#                                 "name": "leaky_re_lu_2",
#                                 "trainable": false,
#                                 "alpha": 0.20000000298023224
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "discriminator_conv_1",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "discriminator_conv_2",
#                             "class_name": "Conv2D",
#                             "config": {
#                                 "name": "discriminator_conv_2",
#                                 "trainable": false,
#                                 "filters": 128,
#                                 "kernel_size": [
#                                     5,
#                                     5
#                                 ],
#                                 "strides": [
#                                     2,
#                                     2
#                                 ],
#                                 "padding": "same",
#                                 "data_format": "channels_last",
#                                 "dilation_rate": [
#                                     1,
#                                     1
#                                 ],
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "leaky_re_lu_2",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "leaky_re_lu_3",
#                             "class_name": "LeakyReLU",
#                             "config": {
#                                 "name": "leaky_re_lu_3",
#                                 "trainable": false,
#                                 "alpha": 0.20000000298023224
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "discriminator_conv_2",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "discriminator_conv_3",
#                             "class_name": "Conv2D",
#                             "config": {
#                                 "name": "discriminator_conv_3",
#                                 "trainable": false,
#                                 "filters": 128,
#                                 "kernel_size": [
#                                     5,
#                                     5
#                                 ],
#                                 "strides": [
#                                     1,
#                                     1
#                                 ],
#                                 "padding": "same",
#                                 "data_format": "channels_last",
#                                 "dilation_rate": [
#                                     1,
#                                     1
#                                 ],
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "leaky_re_lu_3",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "leaky_re_lu_4",
#                             "class_name": "LeakyReLU",
#                             "config": {
#                                 "name": "leaky_re_lu_4",
#                                 "trainable": false,
#                                 "alpha": 0.20000000298023224
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "discriminator_conv_3",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "flatten_1",
#                             "class_name": "Flatten",
#                             "config": {
#                                 "name": "flatten_1",
#                                 "trainable": false,
#                                 "data_format": "channels_last"
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "leaky_re_lu_4",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         },
#                         {
#                             "name": "dense_1",
#                             "class_name": "Dense",
#                             "config": {
#                                 "name": "dense_1",
#                                 "trainable": false,
#                                 "units": 1,
#                                 "activation": "linear",
#                                 "use_bias": true,
#                                 "kernel_initializer": {
#                                     "class_name": "RandomNormal",
#                                     "config": {
#                                         "mean": 0.0,
#                                         "stddev": 0.02,
#                                         "seed": null
#                                     }
#                                 },
#                                 "bias_initializer": {
#                                     "class_name": "Zeros",
#                                     "config": {}
#                                 },
#                                 "kernel_regularizer": null,
#                                 "bias_regularizer": null,
#                                 "activity_regularizer": null,
#                                 "kernel_constraint": null,
#                                 "bias_constraint": null
#                             },
#                             "inbound_nodes": [
#                                 [
#                                     [
#                                         "flatten_1",
#                                         0,
#                                         0,
#                                         {}
#                                     ]
#                                 ]
#                             ]
#                         }
#                     ],
#                     "input_layers": [
#                         [
#                             "discriminator_input",
#                             0,
#                             0
#                         ]
#                     ],
#                     "output_layers": [
#                         [
#                             "dense_1",
#                             0,
#                             0
#                         ]
#                     ]
#                 },
#                 "inbound_nodes": [
#                     [
#                         [
#                             "model_2",
#                             1,
#                             0,
#                             {}
#                         ]
#                     ]
#                 ]
#             }
#         ],
#         "input_layers": [
#             [
#                 "model_input",
#                 0,
#                 0
#             ]
#         ],
#         "output_layers": [
#             [
#                 "model_1",
#                 1,
#                 0
#             ]
#         ]
#     },
#     "keras_version": "2.2.4",
#     "backend": "tensorflow"
# }

# %%
#gan.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
gan.discriminator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# discriminator_input (InputLa (None, 32, 32, 3)         0
# _________________________________________________________________
# discriminator_conv_0 (Conv2D (None, 16, 16, 64)        4864
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 16, 16, 64)        0
# _________________________________________________________________
# discriminator_conv_1 (Conv2D (None, 8, 8, 64)          102464
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 8, 8, 64)          0
# _________________________________________________________________
# discriminator_conv_2 (Conv2D (None, 4, 4, 128)         204928
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# discriminator_conv_3 (Conv2D (None, 4, 4, 128)         409728
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2049
# =================================================================
# Total params: 1,448,066
# Trainable params: 724,033
# Non-trainable params: 724,033
# _________________________________________________________________
# /Users/davidfoster/.virtualenvs/gdl/lib/python3.6/site-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'

# %%
gan.generator.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# generator_input (InputLayer) (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4096)              413696
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 4096)              16384
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 4096)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 8, 8, 64)          0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# generator_conv_t_0 (Conv2DTr (None, 16, 16, 128)       204928
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 128)       512
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 16, 128)       0
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 32, 32, 128)       0
# _________________________________________________________________
# generator_conv_t_1 (Conv2DTr (None, 32, 32, 64)        204864
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# generator_conv_t_2 (Conv2DTr (None, 32, 32, 64)        102464
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 32, 32, 64)        0
# _________________________________________________________________
# generator_conv_t_3 (Conv2DTr (None, 32, 32, 3)         4803
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 32, 3)         0
# =================================================================
# Total params: 948,163
# Trainable params: 939,459
# Non-trainable params: 8,704
# _________________________________________________________________

# %% [markdown]
# ## training

# %%
gan.train(     
    x_train
    , batch_size = 128
    , epochs = 2000
    , run_folder = RUN_FOLDER
    , print_every_n_batches = 10
    , n_critic = 5
    , clip_threshold = 0.01
)
# Out:
# 0 (5, 1) [D loss: (-0.001, 0.000, -0.000)]  [G loss: -0.001]
# 1 (5, 1) [D loss: (-0.001, 0.001, -0.000)]  [G loss: -0.001]
# 2 (5, 1) [D loss: (-0.001, 0.001, -0.000)]  [G loss: -0.001]
# 3 (5, 1) [D loss: (-0.002, 0.001, -0.000)]  [G loss: -0.001]
# 4 (5, 1) [D loss: (-0.002, 0.001, -0.000)]  [G loss: -0.001]
# 5 (5, 1) [D loss: (-0.003, 0.002, -0.001)]  [G loss: -0.001]
# 6 (5, 1) [D loss: (-0.004, 0.003, -0.001)]  [G loss: -0.003]
# 7 (5, 1) [D loss: (-0.004, 0.003, -0.001)]  [G loss: -0.001]
# 8 (5, 1) [D loss: (-0.004, 0.003, -0.001)]  [G loss: -0.002]
# 9 (5, 1) [D loss: (-0.007, 0.002, -0.002)]  [G loss: 0.001]
# 10 (5, 1) [D loss: (-0.004, 0.005, 0.001)]  [G loss: -0.001]
# 11 (5, 1) [D loss: (-0.003, 0.002, -0.000)]  [G loss: -0.000]
# 12 (5, 1) [D loss: (-0.006, -0.001, -0.004)]  [G loss: 0.002]
# 13 (5, 1) [D loss: (-0.006, 0.005, -0.001)]  [G loss: 0.002]
# 14 (5, 1) [D loss: (-0.004, 0.003, -0.001)]  [G loss: 0.004]
# 15 (5, 1) [D loss: (-0.005, -0.010, -0.008)]  [G loss: 0.008]
# 16 (5, 1) [D loss: (-0.001, 0.007, 0.003)]  [G loss: 0.003]
# 17 (5, 1) [D loss: (-0.001, 0.000, -0.001)]  [G loss: 0.003]
# 18 (5, 1) [D loss: (-0.001, -0.004, -0.003)]  [G loss: 0.004]
# 19 (5, 1) [D loss: (-0.000, -0.002, -0.001)]  [G loss: 0.003]
# 20 (5, 1) [D loss: (-0.001, 0.001, 0.000)]  [G loss: 0.002]
# 21 (5, 1) [D loss: (-0.001, -0.000, -0.000)]  [G loss: 0.001]
# 22 (5, 1) [D loss: (-0.001, -0.001, -0.001)]  [G loss: 0.001]
# 23 (5, 1) [D loss: (-0.001, 0.001, -0.000)]  [G loss: 0.001]
# 24 (5, 1) [D loss: (-0.002, -0.000, -0.001)]  [G loss: 0.001]
# 25 (5, 1) [D loss: (-0.003, 0.001, -0.001)]  [G loss: 0.001]
# 26 (5, 1) [D loss: (-0.005, 0.001, -0.002)]  [G loss: 0.001]
# 27 (5, 1) [D loss: (-0.004, 0.002, -0.001)]  [G loss: 0.001]
# 28 (5, 1) [D loss: (-0.004, 0.002, -0.001)]  [G loss: 0.001]
# 29 (5, 1) [D loss: (-0.004, 0.002, -0.001)]  [G loss: 0.000]
# 30 (5, 1) [D loss: (-0.003, 0.001, -0.001)]  [G loss: 0.001]
# 31 (5, 1) [D loss: (-0.004, -0.002, -0.003)]  [G loss: -0.002]
# 32 (5, 1) [D loss: (-0.003, 0.002, -0.001)]  [G loss: 0.001]
# 33 (5, 1) [D loss: (-0.002, -0.000, -0.001)]  [G loss: 0.002]
# 34 (5, 1) [D loss: (-0.003, 0.001, -0.001)]  [G loss: 0.001]
# 35 (5, 1) [D loss: (-0.002, -0.001, -0.001)]  [G loss: 0.002]
# 36 (5, 1) [D loss: (-0.002, 0.001, -0.001)]  [G loss: 0.002]
# 37 (5, 1) [D loss: (-0.001, -0.000, -0.001)]  [G loss: 0.004]
# 38 (5, 1) [D loss: (-0.002, -0.002, -0.002)]  [G loss: 0.004]
# 39 (5, 1) [D loss: (-0.001, 0.001, 0.000)]  [G loss: 0.004]
# 40 (5, 1) [D loss: (-0.002, -0.001, -0.001)]  [G loss: 0.004]
# 41 (5, 1) [D loss: (-0.001, -0.001, -0.001)]  [G loss: 0.005]
# 42 (5, 1) [D loss: (-0.002, -0.010, -0.006)]  [G loss: 0.006]
# 43 (5, 1) [D loss: (0.002, -0.009, -0.003)]  [G loss: 0.004]
# 44 (5, 1) [D loss: (0.001, -0.001, 0.000)]  [G loss: 0.009]
# 45 (5, 1) [D loss: (0.002, -0.010, -0.004)]  [G loss: 0.013]
# 46 (5, 1) [D loss: (0.001, -0.002, -0.000)]  [G loss: 0.007]
# 47 (5, 1) [D loss: (0.003, -0.018, -0.007)]  [G loss: 0.007]
# 48 (5, 1) [D loss: (0.006, -0.024, -0.009)]  [G loss: 0.005]
# 49 (5, 1) [D loss: (0.003, -0.001, 0.001)]  [G loss: 0.006]
# 50 (5, 1) [D loss: (0.003, -0.020, -0.008)]  [G loss: 0.019]
# 51 (5, 1) [D loss: (0.003, -0.013, -0.005)]  [G loss: 0.018]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py in as_dtype(type_value)
#     680   try:
# --> 681     return _INTERN_TABLE[type_value]
#     682   except KeyError:
#
# KeyError: 'float32'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-6578df823314> in <module>
#       6     , print_every_n_batches = 10
#       7     , n_critic = 5
# ----> 8     , clip_threshold = 0.01
#       9 )
#
# ~/Git/Personal/GDL/generative_deep_learning_code/models/WGAN_old.py in train(self, x_train, batch_size, epochs, run_folder, print_every_n_batches, n_critic, clip_threshold, using_generator)
#     285             d_acc = [0,0]
#     286             while (d_counter < n_critic or d_acc[0] <= 0.5 or d_acc[1] <= 0.5) and d_counter < max_n_critic:
# --> 287                 d_loss, d_acc = self.train_discriminator(x_train, batch_size, clip_threshold, using_generator)
#     288                 d_counter += 1
#     289
#
# ~/Git/Personal/GDL/generative_deep_learning_code/models/WGAN_old.py in train_discriminator(self, x_train, batch_size, clip_threshold, using_generator)
#     261             weights = l.get_weights()
#     262             weights = [np.clip(w, -clip_threshold, clip_threshold) for w in weights]
# --> 263             l.set_weights(weights)
#     264
#     265         return (d_loss_real, d_loss_fake, d_loss), (d_acc_real, d_acc_fake, d_acc)
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/keras/engine/base_layer.py in set_weights(self, weights)
#    1057                                  'provided weight shape ' + str(w.shape))
#    1058             weight_value_tuples.append((p, w))
# -> 1059         K.batch_set_value(weight_value_tuples)
#    1060
#    1061     def get_weights(self):
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in batch_set_value(tuples)
#    2456         for x, value in tuples:
#    2457             value = np.asarray(value, dtype=dtype(x))
# -> 2458             tf_dtype = tf.as_dtype(x.dtype.name.split('_')[0])
#    2459             if hasattr(x, '_assign_placeholder'):
#    2460                 assign_placeholder = x._assign_placeholder
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py in as_dtype(type_value)
#     679
#     680   try:
# --> 681     return _INTERN_TABLE[type_value]
#     682   except KeyError:
#     683     pass
#
# KeyboardInterrupt:

# %%
plt.plot([x[1] for x in gan.d_losses], color='green', linewidth=0.5)
plt.plot([x[2] for x in gan.d_losses], color='red', linewidth=0.5)

plt.plot(gan.g_losses, color='orange', linewidth=1)

plt.plot([x[0] for x in gan.d_losses], color='black', linewidth=1)
